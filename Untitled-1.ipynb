# %%
import pydataset
# pydataset.data()
df = pydataset.data('mtcars')
df
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
import pandas as pd 
# df = pd.DataFrame({'name' : ['김지훈','이유진','박동현','김민지'],
#                    'english' : [90,80,60,70],
#                    'math' : [50,60,100,20]})
# df
# df['english']
# sum(df['english'])
# sum(df['english']) /4



# df_exam = pd.read_excel('excel_exam.xlsx')
# df_exam
# sum(df_exam['english']) / len(df_exam['english'])

# df_exam_novar = pd.read_excel('excel_exam_novar.xlsx')
# df_exam_novar

# df_exam_novar = pd.read_excel('excel_exam_novar.xlsx',header = None)
# df_exam_novar

# df_csv_exam = pd.read_csv('exam.csv')
# df_csv_exam

# df_midterm = pd.DataFrame({'english' : [90,80,60,70],
#                            'math': [50,60,70,80],
#                            'nlclass': [1,1,2,2]})
# df_midterm

# df_midterm.to_csv('exam.csv')
# df_midterm.to_csv('exam.csv',index=False)

# %%
#데이터 파악

import pandas as pd 
exam = pd.read_csv('exam.csv')
mtcar = pd.read_csv('mtcars.csv')
# exam.head()
# exam.head(10)
# mtcar.tail()
# mtcar.tail(10)
# mtcar.shape     데이터가 몇행 몇열인지 \
# mtcar.info()     변수 속성
# mtcar.describe()      요약 통계량 구하기
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
#실습

import pandas as pd 
mpg = pd.read_csv('mpg.csv')
# mpg.head()
# mpg.tail()
# mpg.shape
# mpg.info()
# mpg.describe()
mpg.describe(include='all')
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
#변수명 바꾸기

import pandas as pd 

df_raw = pd.DataFrame({'var1' : [1,2,1],
                       'var2' : [2,3,2]})
df_new = df_raw.copy()
df_new = df_new.rename(columns= {'var2':'V2'})
df_new
# Out:
#    var1  V2
# 0     1   2
# 1     2   3
# 2     1   2

# %%
#파생변수
import pandas as pd 
df = pd.DataFrame({'var1' : [1,2,1],
                    'var2' : [2,3,2]})
df['var_sum'] = df['var1'] + df['var2'] #파생변수 만들기
# df
mpg['total'] = (mpg['city']+mpg['hwy']) /2
mpg.head()

# sum(mpg['total']) / len(mpg)
# mpg['total'].mean()

mpg['total'].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt # 시각화 라이브러리 불러오기

# 1. 데이터 불러오기 및 전처리
# mpg = pd.read_csv('mpg.csv')
mpg['total'] = (mpg['cty'] + mpg['hwy']) / 2 
# mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')

# # 2. 빈도수 구하기
# count_test = mpg['test'].value_counts()

# # 3. 막대 그래프 그리기
# count_test.plot.bar(rot =0)

# # 4. 그래프 출력하기
# plt.show()


mpg['grade'] = np.where(mpg['total']>=30,'A',
               np.where(mpg['total'] >= 20,'B','C') )
mpg.head()

# count_grade = mpg['grade'].value_counts()
count_grade = mpg['grade'].value_counts().sort_index()
count_grade.plot.bar(rot = 0)

plt.show()

# %%
import pandas as pd
exam = pd.read_csv('exam.csv')
exam.query('nclass ==1') #  exam에서 nclass가 1인 경우만 출력
exam.query('nclass !=1') #  1이 아닌 경우 

exam.query('nclass ==1 & math >= 50')
exam.query('math > 50') #   수학 점수가 50점 초과인 경우
exam.query('math < 50')#   수학 점수가 50점 미만인 경우
exam.query('math >= 50')#   수학 점수가 50점 이상인 경우
exam.query('math <= 50')#   수학 점수가 50점 이하인 경우
exam.query('english >=9- | math < 50')#   두 조건 중 하나 이상 충족
exam.query('nclass ==1 | nclass ==3 |nclass ==5')#   목록에 해당하는 행 출력
exam.query('nclass in [1,3,5]') #   1,3,5반에 해당하면 추출

df = pd.DataFrame({'sex':['F','M','F','M'],
                   'country': ['Korea','China','USA']})
df.query('sex ==F & country == "Korea')

# %%
import pandas as pd
import numpy as np
mpg = pd.read_csv('mpg.csv')
displ1 = mpg['displ <= 4']
displ1['hwy'].mean()
displ2 = mpg['displ >= 5']
displ2['hwy'].mean()


mpg_audi = mpg.query('manufacturer == "audi"')
mpg_toyota = mpg.query('manufacturer == "toyota"')

mpg_audi['cty'].mean()
mpg_toyota['cty'].mean()

mpg_new = mpg.query('manufacturer in ["chevrolet","ford","honda"]')
mpg_new['hwy'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
import pandas as pd
exam['math']
# exam[['nclass','math','english']]
# exam.drop(columns='math')
exam.drop(columns=['math','english'])
exam.query('ncalss == 1')['english']
exam.query('math >= 50')[['id','math']]

# %%
import pandas as pd
mpg = pd.read_csv('mpg.csv')

mpg[['category','cty']]
mpg_new = mpg[['category','cty']]
mpg_new.query('category == suv')['cty'].mean()
mpg_new.query('category == compact')['cty'].mean()
# Out:
#     category  cty
# 0    compact   18
# 1    compact   21
# 2    compact   20
# 3    compact   21
# 4    compact   16
# ..       ...  ...
# 229  midsize   19
# 230  midsize   21
# 231  midsize   16
# 232  midsize   18
# 233  midsize   17
#
# [234 rows x 2 columns]

# %%
import pandas as pd
exam = pd.read_csv('exam.csv')
